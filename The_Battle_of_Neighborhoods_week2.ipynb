# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods (Week 2)

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# **Problem description**: Opening a restaurant in Chicago where competition and crime rate is low.
#
# **Taget audience**: pople who would like to open a **restaurant in Chicago** at a *safe* neighborhood with *relatively low competition*.
#
# **Why it is ipmortant**:
# * Low competition is better.
# * Customers prefer safer areas.
#
# *NOTE: During my analysis I will concentrate on the more serious, more violent crimes. Because in my opinion more violent crimes matter the most.*

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# #### 1. Chicago crime data

# %% [markdown]
# I will use the [Chicago's city offical website](https://data.cityofchicago.org/api/views/3i3m-jwuy/rows.csv?accessType=DOWNLOAD) for crime data. The latest data available is from 2018, so I will use that. After downloading the CSV I will convert it to a DataFrame. As I mentioned above I will concentrate on the more serious/violent crimes.

# %% [markdown]
# I will drop lines considering less serious/violent crimes:
# * burglary
# * concealed carry license violation
# * criminal trespass
# * deceptive practice
# * gambling
# * interference with public officer
# * liquor law violation
# * motor vehicle theft
# * non-criminal
# * non-criminal (subject specified)
# * obscenity
# * other narcotic violation
# * other offense
# * prostitution
# * public indecency
# * public peace violation
# * theft

# %% [markdown]
# **I will concentrate on the following type of crimes:**
# * arson
# * assault
# * crim sexual assault
# * criminal damage
# * criminal sexual assault
# * homicide
# * human trafficking
# * intimidation
# * kidnapping
# * narcotics
# * offense involving children
# * robbery
# * sex offense
# * stalking
# * weapons violation

# %% [markdown]
# Chicago has 77 neighborhoods. I will check the (total number of crimes)/(neighboorhood population) for neighborhood and I will continue with the 20 safest neighboorhoods.

# %%
#Downloading the data from the linke mentioned above:
# !wget -q -O 'chicago_crime.csv' https://data.cityofchicago.org/api/views/3i3m-jwuy/rows.csv?accessType=DOWNLOAD

# %%
#Importing libaries:
import numpy as np
import pandas as pd
pd.set_option('display.precision',15)
import json
from geopy.geocoders import Nominatim 
import requests 
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium

# %%
df_crime=pd.read_csv('chicago_crime.csv')

# %%
df_crime.head()
# Out:
#          ID Case Number                    Date                Block  IUCR  \
# 0  11317463    JB266425  05/16/2018 07:10:00 PM  060XX N LINCOLN AVE  0326
# 1  11346980    JB304586  06/13/2018 12:27:00 AM      027XX W 63RD ST  0610
# 2  11540961    JB560480  12/05/2018 12:00:00 AM    002XX S HOYNE AVE  1562
# 3  11433411    JB418440  09/01/2018 08:32:00 PM  009XX N HARDING AVE  041A
# 4  11394797    JB368524  07/28/2018 02:27:00 AM   110XX S HALSTED ST  0263
#
#               Primary Type                              Description  \
# 0                  ROBBERY           AGGRAVATED VEHICULAR HIJACKING
# 1                 BURGLARY                           FORCIBLE ENTRY
# 2              SEX OFFENSE         AGGRAVATED CRIMINAL SEXUAL ABUSE
# 3                  BATTERY                     AGGRAVATED - HANDGUN
# 4  CRIMINAL SEXUAL ASSAULT  AGGRAVATED - KNIFE / CUTTING INSTRUMENT
#
#                      Location Description  Arrest  Domestic  ...  Ward  \
# 0  PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False  ...  50.0
# 1                         OTHER (SPECIFY)   False     False  ...  17.0
# 2                               RESIDENCE   False     False  ...  27.0
# 3                                   ALLEY   False     False  ...  37.0
# 4                                   ALLEY    True     False  ...  34.0
#
#    Community Area  FBI Code  X Coordinate Y Coordinate  Year  \
# 0              13        03     1153623.0    1940355.0  2018
# 1              66        05     1159376.0    1862766.0  2018
# 2              28        17     1162441.0    1898955.0  2018
# 3              23       04B     1149884.0    1905974.0  2018
# 4              49        02     1172953.0    1831551.0  2018
#
#                Updated On            Latitude           Longitude  \
# 0  06/11/2020 03:46:39 PM  41.992175988000000 -87.710287127000001
# 1  06/05/2020 03:46:23 PM  41.779147989000002 -87.691261103999992
# 2  06/04/2020 03:45:42 PM  41.878391286999999 -87.679013963999992
# 3  06/03/2020 03:45:09 PM  41.897905615999996 -87.724938080000001
# 4  06/03/2020 03:45:09 PM  41.693200858000004 -87.642405218999997
#
#                         Location
# 0  (41.992175988, -87.710287127)
# 1  (41.779147989, -87.691261104)
# 2  (41.878391287, -87.679013964)
# 3   (41.897905616, -87.72493808)
# 4  (41.693200858, -87.642405219)
#
# [5 rows x 22 columns]

# %%
#Dropping unnecessary columns. 
df_crime.drop(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat', 'District', 'Ward', 'FBI Code', 'X Coordinate','Y Coordinate', 'Year', 'Updated On', 'Location'], inplace=True, axis = 1)

# %%
#Checking what columns left
df_crime.columns
# Out:
# Index(['Primary Type', 'Community Area', 'Latitude', 'Longitude'], dtype='object')

# %%
df_crime.head()
# Out:
#               Primary Type  Community Area            Latitude  \
# 0                  ROBBERY              13  41.992175988000000
# 1                 BURGLARY              66  41.779147989000002
# 2              SEX OFFENSE              28  41.878391286999999
# 3                  BATTERY              23  41.897905615999996
# 4  CRIMINAL SEXUAL ASSAULT              49  41.693200858000004
#
#             Longitude
# 0 -87.710287127000001
# 1 -87.691261103999992
# 2 -87.679013963999992
# 3 -87.724938080000001
# 4 -87.642405218999997

# %%
#Selecting the violent crimes. (List if violent crimes are above.)
df_crime = df_crime[(df_crime['Primary Type']=="ARSON") | (df_crime['Primary Type']=="ASSAULT") | (df_crime['Primary Type']=="CRIM SEXUAL ASSAULT") | (df_crime['Primary Type']=="CRIMINAL DAMAGE") | (df_crime['Primary Type']=="CRIMINAL SEXUAL ASSAULT") | (df_crime['Primary Type']=="HOMICIDE") | (df_crime['Primary Type']=="HUMAN TRAFFICKING") | (df_crime['Primary Type']=="INTIMIDATION") | (df_crime['Primary Type']=="KIDNAPPING") | (df_crime['Primary Type']=="NARCOTICS") | (df_crime['Primary Type']=="OFFENSE INVOLVING CHILDREN") | (df_crime['Primary Type']=="ROBBERY") | (df_crime['Primary Type']=="SEX OFFENSE") | (df_crime['Primary Type']=="STALKING") | (df_crime['Primary Type']=="WEAPONS VIOLATION")]

# %%
#I have to drop lines with no longitute or langitude information
df_crime.dropna(subset=["Latitude"], axis=0, inplace=True)
df_crime.dropna(subset=["Longitude"], axis=0, inplace=True)
df_crime.reset_index(drop=True, inplace=True)

# %%
print(df_crime['Primary Type'].value_counts())
# Out:
# CRIMINAL DAMAGE               27700
# ASSAULT                       20342
# NARCOTICS                     12797
# ROBBERY                        9676
# WEAPONS VIOLATION              5444
# OFFENSE INVOLVING CHILDREN     2144
# CRIM SEXUAL ASSAULT            1458
# SEX OFFENSE                    1053
# HOMICIDE                        600
# ARSON                           373
# STALKING                        199
# KIDNAPPING                      172
# INTIMIDATION                    167
# CRIMINAL SEXUAL ASSAULT         105
# HUMAN TRAFFICKING                12
# Name: Primary Type, dtype: int64

# %%
#Checking the final Crime dataframe.
df_crime.head()
# Out:
#                  Primary Type  Community Area            Latitude  \
# 0                     ROBBERY              13  41.992175988000000
# 1                 SEX OFFENSE              28  41.878391286999999
# 2     CRIMINAL SEXUAL ASSAULT              49  41.693200858000004
# 3  OFFENSE INVOLVING CHILDREN              23  41.901788359000001
# 4     CRIMINAL SEXUAL ASSAULT              51  41.702183740000002
#
#             Longitude
# 0 -87.710287127000001
# 1 -87.679013963999992
# 2 -87.642405218999997
# 3 -87.723835954999998
# 4 -87.565137272000001

# %% [markdown]
# As you can se above the Chicago crime dataset is not clean, it only contains the more serious crimes and rows with no lattitude or longitude information have been droped.

# %% [markdown]
# #### 2. Community areas in Chicago

# %% [markdown]
# The name of the community areas can be found on [wikipedia](https://en.wikipedia.org/wiki/Community_areas_in_Chicago). I will get the name of the areas and the population from this source. Unfortunately this does not contains the coordinates, so **I will use geolocator to the the latitude and longitude information.**

# %%
#Loading information from Wikipedia:
areas = pd.read_html("https://en.wikipedia.org/wiki/Community_areas_in_Chicago")

# %%
#pd.read_html returns with a list, but I need a DataFrame:
df_areas = areas[0]

# %%
df_areas.head()
# Out:
#   Number[8]         Name[8]  2017[9] Area (sq mi.)[10]         Area (km2)  \
# 0        01     Rogers Park    55062              1.84  4.770000000000000
# 1        02      West Ridge    76215              3.53  9.140000000000001
# 2        03          Uptown    57973              2.32  6.010000000000000
# 3        04  Lincoln Square    41715              2.56  6.630000000000000
# 4        05    North Center    35789              2.05  5.310000000000000
#
#    2017density (/sq mi.)     2017density (/km2)
# 0  29925.000000000000000  11554.110000000000582
# 1  21590.650000000001455   8336.200000000000728
# 2  24988.360000000000582   9648.059999999999491
# 3  16294.920000000000073   6291.500000000000000
# 4  17458.049999999999272   6740.590000000000146

# %%
#Dropping the last line
df_areas.drop(df_areas.tail(1).index,inplace=True)

# %%
df_areas.drop(['Area (sq mi.)[10]', 'Area (km2)', '2017density (/sq mi.)', '2017density (/km2)'], inplace=True, axis = 1)

# %%
df_areas.columns
# Out:
# Index(['Number[8]', 'Name[8]', '2017[9]'], dtype='object')

# %%
#I need to rename columns to have a more meaningful names
df_areas.rename(columns={'Number[8]':'Area Number', 'Name[8]': 'Area Name', '2017[9]': 'Population'}, inplace=True)

# %%
#There is a badly formatted area name:
df_areas.iat[31, 1] = 'The Loop'

# %%
df_areas.head()
# Out:
#   Area Number       Area Name  Population
# 0          01     Rogers Park       55062
# 1          02      West Ridge       76215
# 2          03          Uptown       57973
# 3          04  Lincoln Square       41715
# 4          05    North Center       35789

# %% [markdown]
# As you can see above we have now the area names and the population of the areas. (The chicago crime dataset contained only an area number.)

# %%
#I will use the funcion below the get the lattitude and longitude information for the Area Names
def locate_area(address):
    raw_string = r"{}".format(address)
    raw_string = raw_string + ', Chicago'
    geolocator = Nominatim(user_agent="to_explorer")
    location = geolocator.geocode(raw_string)
    latitude = location.latitude
    longitude = location.longitude
    print('The geograpical coordinates of {} are {}, {}.'.format(raw_string,latitude, longitude))
    return latitude, longitude

# %%
#Getting the latitude and longitude information for each area.
lat_long=df_areas['Area Name'].apply(locate_area)
# Out:
# The geograpical coordinates of Rogers Park, Chicago are 42.01053135, -87.67074819664808.
# The geograpical coordinates of West Ridge, Chicago are 42.0035482, -87.6962426.
# The geograpical coordinates of Uptown, Chicago are 41.9666299, -87.6555458.
# The geograpical coordinates of Lincoln Square, Chicago are 41.975989850000005, -87.6896163305115.
# The geograpical coordinates of North Center, Chicago are 41.9561073, -87.6791596.
# The geograpical coordinates of Lake View, Chicago are 41.947050000000004, -87.65542878290054.
# The geograpical coordinates of Lincoln Park, Chicago are 41.940297650000005, -87.63811710541756.
# The geograpical coordinates of Near North Side, Chicago are 41.9000327, -87.6344975.
# The geograpical coordinates of Edison Park, Chicago are 42.0057335, -87.81401633833357.
# The geograpical coordinates of Norwood Park, Chicago are 41.9855895, -87.80058173001102.
# The geograpical coordinates of Jefferson Park, Chicago are 41.9697375, -87.7631179.
# The geograpical coordinates of Forest Glen, Chicago are 41.991751550000004, -87.75167396842738.
# The geograpical coordinates of North Park, Chicago are 41.9805872, -87.7208917.
# The geograpical coordinates of Albany Park, Chicago are 41.9719367, -87.7161739.
# The geograpical coordinates of Portage Park, Chicago are 41.9578093, -87.7650594.
# The geograpical coordinates of Irving Park, Chicago are 41.953365, -87.7364471.
# The geograpical coordinates of Dunning, Chicago are 41.952809, -87.7964493.
# The geograpical coordinates of Montclare, Chicago are 41.9253091, -87.8008931.
# The geograpical coordinates of Belmont Cragin, Chicago are 41.9316983, -87.7686699.
# The geograpical coordinates of Hermosa, Chicago are 41.928643, -87.7345019.
# The geograpical coordinates of Avondale, Chicago are 41.9389208, -87.711168.
# The geograpical coordinates of Logan Square, Chicago are 41.9285683, -87.7067931.
# The geograpical coordinates of Humboldt Park, Chicago are 41.9057668, -87.7041737.
# The geograpical coordinates of West Town, Chicago are 41.9014213, -87.6861661.
# The geograpical coordinates of Austin, Chicago are 41.8878759, -87.7648508.
# The geograpical coordinates of West Garfield Park, Chicago are 41.8805878, -87.7292227.
# The geograpical coordinates of East Garfield Park, Chicago are 41.8808657, -87.7028328.
# The geograpical coordinates of Near West Side, Chicago are 41.8800656, -87.6667624.
# The geograpical coordinates of North Lawndale, Chicago are 41.8600324, -87.7183883.
# The geograpical coordinates of South Lawndale, Chicago are 41.8436437, -87.7125544.
# The geograpical coordinates of Lower West Side, Chicago are 41.8541996, -87.6656086.
# The geograpical coordinates of The Loop, Chicago are 41.8755616, -87.6244212.
# The geograpical coordinates of Near South Side, Chicago are 41.8566999, -87.6247738.
# The geograpical coordinates of Armour Square, Chicago are 41.8400333, -87.633107.
# The geograpical coordinates of Douglas, Chicago are 41.8348565, -87.6179536.
# The geograpical coordinates of Oakland, Chicago are 41.8236535, -87.6082424.
# The geograpical coordinates of Fuller Park, Chicago are 41.8180891, -87.6325508.
# The geograpical coordinates of Grand Boulevard, Chicago are 41.8139226, -87.6172724.
# The geograpical coordinates of Kenwood, Chicago are 41.8091444, -87.5979908.
# The geograpical coordinates of Washington Park, Chicago are 41.7925338, -87.6181052.
# The geograpical coordinates of Hyde Park, Chicago are 41.7944464, -87.5939244.
# The geograpical coordinates of Woodlawn, Chicago are 41.7794786, -87.599493.
# The geograpical coordinates of South Shore, Chicago are 41.7587276, -87.5752828.
# The geograpical coordinates of Chatham, Chicago are 41.7411454, -87.6125481.
# The geograpical coordinates of Avalon Park, Chicago are 41.7450346, -87.5886584.
# The geograpical coordinates of South Chicago, Chicago are 41.7345874, -87.5513222.
# The geograpical coordinates of Burnside, Chicago are 41.7300345, -87.596714.
# The geograpical coordinates of Calumet Heights, Chicago are 41.7300347, -87.5792134.
# The geograpical coordinates of Roseland, Chicago are 41.7019787, -87.625881.
# The geograpical coordinates of Pullman, Chicago are 41.6922182, -87.6066039.
# The geograpical coordinates of South Deering, Chicago are 41.6922364, -87.57170331249044.
# The geograpical coordinates of East Side, Chicago are 41.7135693, -87.5327809.
# The geograpical coordinates of West Pullman, Chicago are 41.6750456, -87.637823.
# The geograpical coordinates of Riverdale, Chicago are 41.6678347, -87.6049644.
# The geograpical coordinates of Hegewisch, Chicago are 41.6536462, -87.5469885.
# The geograpical coordinates of Garfield Ridge, Chicago are 41.8036171, -87.74548862491682.
# The geograpical coordinates of Archer Heights, Chicago are 41.8114215, -87.7261651.
# The geograpical coordinates of Brighton Park, Chicago are 41.8189217, -87.6989421.
# The geograpical coordinates of McKinley Park, Chicago are 41.8316997, -87.6736638.
# The geograpical coordinates of Bridgeport, Chicago are 41.8379385, -87.651028.
# The geograpical coordinates of New City, Chicago are 41.8075333, -87.6564403.
# The geograpical coordinates of West Elsdon, Chicago are 41.7939217, -87.7244978.
# The geograpical coordinates of Gage Park, Chicago are 41.795033, -87.6961636.
# The geograpical coordinates of Clearing, Chicago are 41.780588, -87.7733881.
# The geograpical coordinates of West Lawn, Chicago are 41.7728107, -87.722275.
# The geograpical coordinates of Chicago Lawn, Chicago are 41.7750332, -87.6964408.
# The geograpical coordinates of West Englewood, Chicago are 41.7780891, -87.6667177.
# The geograpical coordinates of Englewood, Chicago are 41.7797559, -87.6458836.
# The geograpical coordinates of Greater Grand Crossing, Chicago are 41.7668861, -87.62084461319708.
# The geograpical coordinates of Ashburn, Chicago are 41.7475332, -87.7111628.
# The geograpical coordinates of Auburn Gresham, Chicago are 41.74338725, -87.6560415931265.
# The geograpical coordinates of Beverly, Chicago are 41.7181532, -87.6717674.
# The geograpical coordinates of Washington Heights, Chicago are 41.7064229, -87.65616.
# The geograpical coordinates of Mount Greenwood, Chicago are 41.6980891, -87.7086616.
# The geograpical coordinates of Morgan Park, Chicago are 41.6903117, -87.6667156.
# The geograpical coordinates of O'Hare, Chicago are 41.97310105, -87.90676788547228.
# The geograpical coordinates of Edgewater, Chicago are 41.9833689, -87.6639516.

# %%
#Converting lat_long to a DataFrame and merging it with the area info DataFrame
lat_long = lat_long.to_frame()
lat_long = pd.DataFrame(lat_long['Area Name'].tolist(), index=lat_long.index)
lat_long.columns = ['Latitude', 'Longitude']
df_areas = pd.concat([df_areas, lat_long], axis=1)
df_areas.head(15)
# Out:
#    Area Number        Area Name  Population            Latitude  \
# 0           01      Rogers Park       55062  42.010531350000001
# 1           02       West Ridge       76215  42.003548199999997
# 2           03           Uptown       57973  41.966629900000001
# 3           04   Lincoln Square       41715  41.975989850000005
# 4           05     North Center       35789  41.956107299999999
# 5           06        Lake View      100470  41.947050000000004
# 6           07     Lincoln Park       67710  41.940297650000005
# 7           08  Near North Side       88893  41.900032699999997
# 8           09      Edison Park       11605  42.005733499999998
# 9           10     Norwood Park       37089  41.985589500000003
# 10          11   Jefferson Park       26808  41.969737500000001
# 11          12      Forest Glen       19019  41.991751550000004
# 12          13       North Park       18842  41.980587200000002
# 13          14      Albany Park       51992  41.971936700000001
# 14          15     Portage Park       64307  41.957809300000001
#
#              Longitude
# 0  -87.670748196648077
# 1  -87.696242600000005
# 2  -87.655545799999999
# 3  -87.689616330511498
# 4  -87.679159600000006
# 5  -87.655428782900543
# 6  -87.638117105417564
# 7  -87.634497499999995
# 8  -87.814016338333573
# 9  -87.800581730011018
# 10 -87.763117899999997
# 11 -87.751673968427383
# 12 -87.720891699999996
# 13 -87.716173900000001
# 14 -87.765059399999998

# %% [markdown]
# Now we have the necessary data:
# * The Area Number
# * The Area Name
# * The population of the given areas
# * Latitude and Longitude information

# %% [markdown]
# #### 3. Foursquare

# %% [markdown]
# I will use foursquare to check competition in the safest 20 neighboorhoods.I will select 5 of them to open a restaurant in one of them.

# %% [markdown]
# **Important note: I will be able to do this once the analisys is done.** Note in this section.

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# 1. I downloaded the Chicago crime information as a CSV format. I converted the CSV into a pandas dataframe. I dropped all unnecessary columns and those rows which did not have the longitude and longitude information. After this I dropped rows with less serios crimes.
# In the **analysis section** I will select the 20 most peaceful neighborhoods.

# %% [markdown]
# 2. The crime dataset did not include area information such as: the name and population of the area.
# Fortunately, this information is on Wikipedia. I used pandas again to get this info. However I was still missing the latitude and longitude information. I used the **geolocator** to get this information.

# %% [markdown]
# In the analysis section I will perform the following:
# * I will select the 20 safest neighborhoods. I will check the (total crime of the given area)/ total population of the given area.
# * I will use forsquare to check compatition.

# %% [markdown]
# In the conclusion section I will make the recommendations regarding where to open a restaurant.

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# Let's perform our analysis. Which areas are the safest?

# %% [markdown]
# Calculating the total crime per neighborhood:

# %%
df_areas.set_index('Area Number', inplace = True)
df_sumcrime = df_crime['Community Area'].value_counts()
df_sumcrime = df_sumcrime.to_frame()
df_sumcrime.index.name = 'Area Number'
df_sumcrime = df_sumcrime.sort_values(['Area Number'], ascending=True, axis=0)
df_sumcrime.columns = ['Number of violent crimes']
df_areas.index = df_areas.index.map(int)
df_sumcrime.index = df_sumcrime.index.map(int)
df_sumcrime.head(20)
# Out:
#              Number of violent crimes
# Area Number
# 1                                1090
# 2                                1004
# 3                                 855
# 4                                 453
# 5                                 262
# 6                                1031
# 7                                 918
# 8                                1900
# 9                                  53
# 10                                295
# 11                                283
# 12                                 91
# 13                                243
# 14                                722
# 15                                883
# 16                                753
# 17                                390
# 18                                164
# 19                               1362
# 20                                463

# %% [markdown]
# Creating the dataframe which containts the information of the neighborhoods:

# %%
df_chicago=pd.concat([df_areas, df_sumcrime],axis=1)
df_chicago.head(10)
# Out:
#                    Area Name  Population            Latitude  \
# Area Number
# 1                Rogers Park       55062  42.010531350000001
# 2                 West Ridge       76215  42.003548199999997
# 3                     Uptown       57973  41.966629900000001
# 4             Lincoln Square       41715  41.975989850000005
# 5               North Center       35789  41.956107299999999
# 6                  Lake View      100470  41.947050000000004
# 7               Lincoln Park       67710  41.940297650000005
# 8            Near North Side       88893  41.900032699999997
# 9                Edison Park       11605  42.005733499999998
# 10              Norwood Park       37089  41.985589500000003
#
#                       Longitude  Number of violent crimes
# Area Number
# 1           -87.670748196648077                      1090
# 2           -87.696242600000005                      1004
# 3           -87.655545799999999                       855
# 4           -87.689616330511498                       453
# 5           -87.679159600000006                       262
# 6           -87.655428782900543                      1031
# 7           -87.638117105417564                       918
# 8           -87.634497499999995                      1900
# 9           -87.814016338333573                        53
# 10          -87.800581730011018                       295

# %%
df_chicago['Crime per person'] = df_chicago['Number of violent crimes']/df_chicago['Population']
df_chicago.head()
# Out:
#                   Area Name  Population            Latitude  \
# Area Number
# 1               Rogers Park       55062  42.010531350000001
# 2                West Ridge       76215  42.003548199999997
# 3                    Uptown       57973  41.966629900000001
# 4            Lincoln Square       41715  41.975989850000005
# 5              North Center       35789  41.956107299999999
#
#                       Longitude  Number of violent crimes   Crime per person
# Area Number
# 1           -87.670748196648077                      1090  0.019795866477789
# 2           -87.696242600000005                      1004  0.013173259856984
# 3           -87.655545799999999                       855  0.014748244872613
# 4           -87.689616330511498                       453  0.010859403092413
# 5           -87.679159600000006                       262  0.007320685126715

# %% [markdown]
# The following table contains the **20 safest neighborhood** of Chicago:

# %%
df_chicago = df_chicago.sort_values(['Crime per person'], ascending=True, axis=0).head(20)
df_chicago.head(20)
# Out:
#                    Area Name  Population            Latitude  \
# Area Number
# 9                Edison Park       11605  42.005733499999998
# 12               Forest Glen       19019  41.991751550000004
# 5               North Center       35789  41.956107299999999
# 74           Mount Greenwood       19277  41.698089099999997
# 10              Norwood Park       37089  41.985589500000003
# 17                   Dunning       43689  41.952809000000002
# 64                  Clearing       25891  41.780588000000002
# 6                  Lake View      100470  41.947050000000004
# 11            Jefferson Park       26808  41.969737500000001
# 72                   Beverly       20822  41.718153200000003
# 4             Lincoln Square       41715  41.975989850000005
# 77                 Edgewater       55965  41.983368900000002
# 18                 Montclare       13830  41.925309100000000
# 13                North Park       18842  41.980587200000002
# 2                 West Ridge       76215  42.003548199999997
# 7               Lincoln Park       67710  41.940297650000005
# 15              Portage Park       64307  41.957809300000001
# 16               Irving Park       54606  41.953364999999998
# 60                Bridgeport       33637  41.837938500000000
# 14               Albany Park       51992  41.971936700000001
#
#                       Longitude  Number of violent crimes   Crime per person
# Area Number
# 9           -87.814016338333573                        53  0.004566996984059
# 12          -87.751673968427383                        91  0.004784688995215
# 5           -87.679159600000006                       262  0.007320685126715
# 74          -87.708661599999999                       142  0.007366291435389
# 10          -87.800581730011018                       295  0.007953840761412
# 17          -87.796449300000006                       390  0.008926732129369
# 64          -87.773388100000005                       260  0.010042099571280
# 6           -87.655428782900543                      1031  0.010261769682492
# 11          -87.763117899999997                       283  0.010556550283497
# 72          -87.671767399999993                       226  0.010853904524061
# 4           -87.689616330511498                       453  0.010859403092413
# 77          -87.663951600000004                       638  0.011399982131689
# 18          -87.800893099999996                       164  0.011858279103398
# 13          -87.720891699999996                       243  0.012896720093408
# 2           -87.696242600000005                      1004  0.013173259856984
# 7           -87.638117105417564                       918  0.013557820115197
# 15          -87.765059399999998                       883  0.013731009065887
# 16          -87.736447100000007                       753  0.013789693440281
# 60          -87.651027999999997                       466  0.013853791955287
# 14          -87.716173900000001                       722  0.013886751807970

# %% [markdown]
# Now have to check to competition in the selected neighborhoods.

# %%
CLIENT_ID = 'JOKAQAZNVJ2RPSL4DCQCNEH04L3QTUKIZE3HLCMWRYFV1LO4' 
CLIENT_SECRET = 'CN1B2WNDQ2YCJBG5OPULS5AYYNIZO3AM5ZDVJ1Q5EK4ESYOG'
VERSION = '20180616'
RADIUS = 500              # I check the 500 meter radius from the center of the neighborhood.
print('My credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# My credentails:
# CLIENT_ID: JOKAQAZNVJ2RPSL4DCQCNEH04L3QTUKIZE3HLCMWRYFV1LO4
# CLIENT_SECRET:CN1B2WNDQ2YCJBG5OPULS5AYYNIZO3AM5ZDVJ1Q5EK4ESYOG

# %%
#I will use the function below to get the number of restaurants for a selected neighborhood:
def number_of_restaurants(latitude, longitude):
    url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&section=food'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, RADIUS)
    results = requests.get(url).json()
    number_of_results = len(results['response']['groups'][0]['items'])
    return number_of_results

# %%
df_chicago['Number of restaurants'] =  np.vectorize(number_of_restaurants)(df_chicago['Latitude'], df_chicago['Longitude'])

# %%
df_chicago = df_chicago.sort_values(['Number of restaurants'], ascending=True, axis=0)

# %% [markdown]
# I select from the safe neighborhoods those which have 10 restaurants or less.

# %%
df_top = df_chicago[df_chicago['Number of restaurants'] <= 10]
df_top.head(20)
# Out:
#                    Area Name  Population            Latitude  \
# Area Number
# 10              Norwood Park       37089  41.985589500000003
# 74           Mount Greenwood       19277  41.698089099999997
# 7               Lincoln Park       67710  41.940297650000005
# 17                   Dunning       43689  41.952809000000002
# 2                 West Ridge       76215  42.003548199999997
# 13                North Park       18842  41.980587200000002
# 72                   Beverly       20822  41.718153200000003
# 12               Forest Glen       19019  41.991751550000004
# 64                  Clearing       25891  41.780588000000002
# 15              Portage Park       64307  41.957809300000001
# 18                 Montclare       13830  41.925309100000000
# 16               Irving Park       54606  41.953364999999998
# 14               Albany Park       51992  41.971936700000001
#
#                       Longitude  Number of violent crimes   Crime per person  \
# Area Number
# 10          -87.800581730011018                       295  0.007953840761412
# 74          -87.708661599999999                       142  0.007366291435389
# 7           -87.638117105417564                       918  0.013557820115197
# 17          -87.796449300000006                       390  0.008926732129369
# 2           -87.696242600000005                      1004  0.013173259856984
# 13          -87.720891699999996                       243  0.012896720093408
# 72          -87.671767399999993                       226  0.010853904524061
# 12          -87.751673968427383                        91  0.004784688995215
# 64          -87.773388100000005                       260  0.010042099571280
# 15          -87.765059399999998                       883  0.013731009065887
# 18          -87.800893099999996                       164  0.011858279103398
# 16          -87.736447100000007                       753  0.013789693440281
# 14          -87.716173900000001                       722  0.013886751807970
#
#              Number of restaurants
# Area Number
# 10                               0
# 74                               1
# 7                                1
# 17                               2
# 2                                2
# 13                               4
# 72                               5
# 12                               5
# 64                               8
# 15                               8
# 18                               8
# 16                              10
# 14                              10

# %% [markdown]
# ## Results and Discussion <a name="results"></a>

# %% [markdown]
# <span style="color:blue">**According to my analisys the following neighborhoods have low crime rate and low compatition:**</span>.

# %%
df_top['Area Name'].to_frame()
# Out:
#                    Area Name
# Area Number
# 10              Norwood Park
# 74           Mount Greenwood
# 7               Lincoln Park
# 17                   Dunning
# 2                 West Ridge
# 13                North Park
# 72                   Beverly
# 12               Forest Glen
# 64                  Clearing
# 15              Portage Park
# 18                 Montclare
# 16               Irving Park
# 14               Albany Park

# %%
geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode('Chicago')
latitude = location.latitude
longitude = location.longitude
chicago_map = folium.Map(location=[latitude, longitude], zoom_start=10)

title_html = '''
             <h3 align="center" style="font-size:20px"><b>Chicago good neighborhoods for restaurants.</b></h3>
             '''
chicago_map.get_root().html.add_child(folium.Element(title_html))

neighborhoods = folium.map.FeatureGroup()
for lat, lng, in zip(df_top.Latitude, df_top.Longitude):
    neighborhoods.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=5, 
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

latitudes = list(df_top.Latitude)
longitudes = list(df_top.Longitude)
labels = list(df_top['Area Name'])

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(chicago_map)    
    

chicago_map.add_child(neighborhoods)
chicago_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# In the north there are some good candidates very close to eachother.

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# The goal of the project was to identify safe neighborhoods in Chicago with quite low competition in food services.
# During my analisys I concentrated on the more serious crimes.

# %% [markdown]
# I was able to identify 13 neighborhoods. I would concentrate on the neighborhoods located in the north, since there are a number of good candidates very close to eachother.
